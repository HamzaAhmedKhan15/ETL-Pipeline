# %% [markdown]
#  ```
#                                                                GROUP MEMBERS:
#
#                                                    |     Hamza Ahmed Khan  (CT-35)     |
#                                                    |        Saim Ahmed  (CT-19)        |
#                                                    |      M. Abdul Rafay  (CT-50)      |
#                                                    |    M. Arqam Khursheed  (CT-18)    |
#
#                                                             COURSE CODE:  CT-463
#
#                                                   COURSE TITLE: DATA WAREHOUSING MINING
#
#                                                              ( Assignment # 1 )
#
#
# ```

# %% [markdown]
# # Step 1 : Data Extraction
#
# Getting started with our ETL (Extract, Transform, Load) journey, the first step is data extraction. With Python, we're gathering valuable pieces of data from three different sources.

# %% [markdown]
# ###*DATASET 1:* *Customer Analysis*
#
# This part of dataset consist of Customer Details like Name, ID, Country, City, Postal Code etc which are required to purchase any product online.
# The whole dataset is fetched from Kaggle.com

# %%
# Importing dataset 1

import pandas as pd
customer_df= pd.read_csv('/content/Customer_Book.csv', encoding="latin-1")

customer_df
# Out:
#      Row ID Customer ID  Customer Name      Segment Country/Region  \
# 0         1    DP-13000  Darren Powers  Replacement  United States
# 1         2    PO-19195  Phillina Ober        Other  United States
# 2         3    PO-19195  Phillina Ober        Other  United States
# 3         4    PO-19195  Phillina Ober        Other  United States
# 4         5    MB-18085     Mick Brown  Replacement  United States
# ..      ...         ...            ...          ...            ...
# 292     293    AH-10690  Anna Häberlin    Servicing  United States
# 293     294    RD-19585       Rob Dowd  Replacement  United States
# 294     295    SC-20020     Sam Craven  Replacement  United States
# 295     296    SC-20020     Sam Craven  Replacement  United States
# 296     297    RD-19585       Rob Dowd  Replacement  United States
#
#                City State/Province Postal Code   Region
# 0           Houston          Texas       77095  Central
# 1        Naperville       Illinois       60540  Central
# 2        Naperville       Illinois       60540  Central
# 3        Naperville       Illinois       60540  Central
# 4      Philadelphia   Pennsylvania       19143     East
# ..              ...            ...         ...      ...
# 292  Virginia Beach       Virginia       23464    South
# 293          Athens        Georgia       30605    South
# 294         Houston          Texas       77095  Central
# 295         Houston          Texas       77095  Central
# 296          Athens        Georgia       30605    South
#
# [297 rows x 9 columns]

# %% [markdown]
# ###*DATASET 2:* *Product Sales Analysis*
#
# This part of dataset consist of Product details and sales data like Product ID, Category, Sub-Category, Sales, Quantity etc. The whole dataset is fetched from Medium.com

# %%
# Importing dataset 2

import pandas as pd

product_df = pd.read_csv('/content/Product_Sales_Book.csv', encoding='latin-1')

product_df
# Out:
#      Row ID       Product ID     Category Sub-Category    Sales  Quantity  \
# 0         1  OFF-PA-10000174  Third Party        Paper   16.448         2
# 1         2  OFF-BI-10004094  Third Party      Binders    3.540         2
# 2         3  OFF-LA-10003223  Third Party       Labels   11.784         3
# 3         4  OFF-ST-10002743  Third Party      Storage  272.736         3
# 4         5  OFF-AR-10003478  Third Party          Art   19.536         3
# ..      ...              ...          ...          ...      ...       ...
# 292     293  FUR-FU-10003192  Direct Sale  Furnishings  177.680         2
# 293     294  OFF-AP-10003842  Third Party   Appliances  154.900         5
# 294     295  OFF-PA-10001593  Third Party        Paper   33.488         7
# 295     296  OFF-PA-10002986  Third Party        Paper   26.720         5
# 296     297  OFF-PA-10004248  Third Party        Paper   15.840         3
#
#      Discount   Profit
# 0         0.2   5.5512
# 1         0.8  -5.4870
# 2         0.2   4.2717
# 3         0.2 -64.7748
# 4         0.2   4.8840
# ..        ...      ...
# 292       0.0  46.1968
# 293       0.0  40.2740
# 294       0.2  10.4650
# 295       0.2   9.3520
# 296       0.0   7.1280
#
# [297 rows x 8 columns]

# %% [markdown]
# ###*DATASET 3:* *Order Analysis*
#
# This dataset consist of Order details whenever an Order is purchased to being shipped. the order details are Order ID, Order Date, Shipping Date, Shipping Mode etc

# %%
# Importing dataset 2

import pandas as pd
order_df= pd.read_csv('/content/Order_Book.csv', encoding='latin-1')
order_df
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode
# 0         1  US-2019-103800  03/01/2019  07/01/2019  Standard Class
# 1         2  US-2019-112326  04/01/2019  08/01/2019  Standard Class
# 2         3  US-2019-112326  04/01/2019  08/01/2019  Standard Class
# 3         4  US-2019-112326  04/01/2019  08/01/2019  Standard Class
# 4         5  US-2019-141817  05/01/2019  12/01/2019  Standard Class
# ..      ...             ...         ...         ...             ...
# 290     293  US-2023-160276  02/04/2023  08/04/2023  Standard Class
# 291     294  US-2023-164315  02/04/2023  08/04/2023  Standard Class
# 292     295  US-2023-157847  02/04/2023  06/04/2023    Second Class
# 293     296  US-2023-157847  02/04/2023  06/04/2023    Second Class
# 294     297  US-2023-164315  02/04/2023  08/04/2023  Standard Class
#
# [295 rows x 5 columns]

# %% [markdown]
# # Step 2 : Data Transformation

# %% [markdown]
# ###*I. DATA DEDUPLICATION*
# Checking if theres any duplicates in the datasets.

# %%
# Check duplicate values in Customer Analysis
duplicate_customers = customer_df[customer_df.duplicated()]
print("Duplicate Customers:")
print(duplicate_customers)

# Check duplicate values in Product Analysis
duplicate_products = product_df[product_df.duplicated()]
print("\nDuplicate Products:")
print(duplicate_products)

# Check duplicate values in Order Analysis
duplicate_orders = order_df[order_df.duplicated()]
print("\nDuplicate Orders:")
print(duplicate_orders)
# Out:
# Duplicate Customers:
# Empty DataFrame
# Columns: [Row ID, Customer ID, Customer Name, Segment, Country/Region, City, State/Province, Postal Code, Region]
# Index: []
#
# Duplicate Products:
# Empty DataFrame
# Columns: [Row ID, Product ID, Category, Sub-Category, Sales, Quantity, Discount, Profit]
# Index: []
#
# Duplicate Orders:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode
# 290     293  US-2023-160276  02/04/2023  08/04/2023  Standard Class
# 291     294  US-2023-164315  02/04/2023  08/04/2023  Standard Class
# 292     295  US-2023-157847  02/04/2023  06/04/2023    Second Class
# 293     296  US-2023-157847  02/04/2023  06/04/2023    Second Class
# 294     297  US-2023-164315  02/04/2023  08/04/2023  Standard Class

# %% [markdown]
# This output indicates that there are no duplicate values in each of the datasets. The empty DataFrames for Duplicate Customers, Duplicate Products, and Duplicate Orders suggest that there are no rows with identical values in the specified columns for each respective dataset.

# %% [markdown]
# ### *II. INNER JOINING / MERGING*

# %% [markdown]
# Performing Inner Join/Merging on all three datasets

# %%
# Perform inner joins on common columns
merged_df = pd.merge(order_df, customer_df, how='inner')
merged_df = pd.merge(merged_df, product_df, how='inner')

# Display the merged DataFrame
merged_df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  US-2019-103800  03/01/2019  07/01/2019  Standard Class    DP-13000
# 1       2  US-2019-112326  04/01/2019  08/01/2019  Standard Class    PO-19195
# 2       3  US-2019-112326  04/01/2019  08/01/2019  Standard Class    PO-19195
# 3       4  US-2019-112326  04/01/2019  08/01/2019  Standard Class    PO-19195
# 4       5  US-2019-141817  05/01/2019  12/01/2019  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City State/Province  \
# 0  Darren Powers  Replacement  United States       Houston          Texas
# 1  Phillina Ober        Other  United States    Naperville       Illinois
# 2  Phillina Ober        Other  United States    Naperville       Illinois
# 3  Phillina Ober        Other  United States    Naperville       Illinois
# 4     Mick Brown  Replacement  United States  Philadelphia   Pennsylvania
#
#   Postal Code   Region       Product ID     Category Sub-Category    Sales  \
# 0       77095  Central  OFF-PA-10000174  Third Party        Paper   16.448
# 1       60540  Central  OFF-BI-10004094  Third Party      Binders    3.540
# 2       60540  Central  OFF-LA-10003223  Third Party       Labels   11.784
# 3       60540  Central  OFF-ST-10002743  Third Party      Storage  272.736
# 4       19143     East  OFF-AR-10003478  Third Party          Art   19.536
#
#    Quantity  Discount   Profit
# 0         2       0.2   5.5512
# 1         2       0.8  -5.4870
# 2         3       0.2   4.2717
# 3         3       0.2 -64.7748
# 4         3       0.2   4.8840

# %% [markdown]
# Datasets are merged together. The merge function automatically identifying common columns between the first two DataFrames (customer_df and product_df) and then merge the result with the third DataFrame (order_df).

# %% [markdown]
# ###*III. DATA ENCRICHMENT*
#
# Data Enrichment refers to adding additional information or deriving new features from existing data.
#
# Assuming we want to calculate the ratio of 'Total Sales'  from 'Sales' and 'Profit Margin' from 'Profit'.

# %%
# Add a Total Sales column
merged_df['Total Sales'] = merged_df['Sales'] * merged_df['Quantity']

# Add a Profit Margin column
merged_df['Profit Margin'] = (merged_df['Profit'] / merged_df['Total Sales']) * 100

# Display the updated DataFrame with the new columns
merged_df
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0         1  US-2019-103800  03/01/2019  07/01/2019  Standard Class
# 1         2  US-2019-112326  04/01/2019  08/01/2019  Standard Class
# 2         3  US-2019-112326  04/01/2019  08/01/2019  Standard Class
# 3         4  US-2019-112326  04/01/2019  08/01/2019  Standard Class
# 4         5  US-2019-141817  05/01/2019  12/01/2019  Standard Class
# ..      ...             ...         ...         ...             ...
# 290     295  US-2023-157847  02/04/2023  06/04/2023    Second Class
# 291     296  US-2023-157847  02/04/2023  06/04/2023    Second Class
# 292     296  US-2023-157847  02/04/2023  06/04/2023    Second Class
# 293     297  US-2023-164315  02/04/2023  08/04/2023  Standard Class
# 294     297  US-2023-164315  02/04/2023  08/04/2023  Standard Class
#
#     Customer ID  Customer Name      Segment Country/Region          City  ...  \
# 0      DP-13000  Darren Powers  Replacement  United States       Houston  ...
# 1      PO-19195  Phillina Ober        Other  United States    Naperville  ...
# 2      PO-19195  Phillina Ober        Other  United States    Naperville  ...
# 3      PO-19195  Phillina Ober        Other  United States    Naperville  ...
# 4      MB-18085     Mick Brown  Replacement  United States  Philadelphia  ...
# ..          ...            ...          ...            ...           ...  ...
# 290    SC-20020     Sam Craven  Replacement  United States       Houston  ...
# 291    SC-20020     Sam Craven  Replacement  United States       Houston  ...
# 292    SC-20020     Sam Craven  Replacement  United States       Houston  ...
# 293    RD-19585       Rob Dowd  Replacement  United States        Athens  ...
# 294    RD-19585       Rob Dowd  Replacement  United States        Athens  ...
#
#       Region       Product ID     Category Sub-Category    Sales Quantity  \
# 0    Central  OFF-PA-10000174  Third Party        Paper   16.448        2
# 1    Central  OFF-BI-10004094  Third Party      Binders    3.540        2
# 2    Central  OFF-LA-10003223  Third Party       Labels   11.784        3
# 3    Central  OFF-ST-10002743  Third Party      Storage  272.736        3
# 4       East  OFF-AR-10003478  Third Party          Art   19.536        3
# ..       ...              ...          ...          ...      ...      ...
# 290  Central  OFF-PA-10001593  Third Party        Paper   33.488        7
# 291  Central  OFF-PA-10002986  Third Party        Paper   26.720        5
# 292  Central  OFF-PA-10002986  Third Party        Paper   26.720        5
# 293    South  OFF-PA-10004248  Third Party        Paper   15.840        3
# 294    South  OFF-PA-10004248  Third Party        Paper   15.840        3
#
#      Discount   Profit  Total Sales  Profit Margin
# 0         0.2   5.5512       32.896      16.875000
# 1         0.8  -5.4870        7.080     -77.500000
# 2         0.2   4.2717       35.352      12.083333
# 3         0.2 -64.7748      818.208      -7.916667
# 4         0.2   4.8840       58.608       8.333333
# ..        ...      ...          ...            ...
# 290       0.2  10.4650      234.416       4.464286
# 291       0.2   9.3520      133.600       7.000000
# 292       0.2   9.3520      133.600       7.000000
# 293       0.0   7.1280       47.520      15.000000
# 294       0.0   7.1280       47.520      15.000000
#
# [295 rows x 22 columns]

# %%
import calendar

# Assuming 'Date' is the column containing date values
merged_df['Order Date'] = pd.to_datetime(merged_df['Order Date'])
merged_df['Order Month'] = merged_df['Order Date'].dt.month
merged_df['Order Month'] = merged_df['Order Month'].apply(lambda x: calendar.month_name[x])
merged_df['Year'] = merged_df['Order Date'].dt.year

yearly_sales = merged_df.groupby('Year')['Sales'].sum().reset_index()
yearly_sales.rename(columns={'Sales': 'Yearly Sales'}, inplace=True)

orders_per_year = merged_df.groupby('Year')['Order ID'].nunique().reset_index()
orders_per_year.rename(columns={'Order ID': 'Orders per Year'}, inplace=True)

orders_per_month = merged_df.groupby(['Year', 'Order Month'])['Order ID'].nunique().reset_index()
orders_per_month.rename(columns={'Order ID': 'Orders per Month'}, inplace=True)

merged_df = pd.merge(merged_df, yearly_sales, on='Year', how='left')
merged_df = pd.merge(merged_df, orders_per_year, on='Year', how='left')
merged_df = pd.merge(merged_df, orders_per_month, on=['Year', 'Order Month'], how='left')

merged_df
# Out:
# <ipython-input-52-3bd6e65da705>:4: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   merged_df['Order Date'] = pd.to_datetime(merged_df['Order Date'])
#      Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0         1  US-2019-103800 2019-03-01  07/01/2019  Standard Class
# 1         2  US-2019-112326 2019-04-01  08/01/2019  Standard Class
# 2         3  US-2019-112326 2019-04-01  08/01/2019  Standard Class
# 3         4  US-2019-112326 2019-04-01  08/01/2019  Standard Class
# 4         5  US-2019-141817 2019-05-01  12/01/2019  Standard Class
# ..      ...             ...        ...         ...             ...
# 290     295  US-2023-157847 2023-02-04  06/04/2023    Second Class
# 291     296  US-2023-157847 2023-02-04  06/04/2023    Second Class
# 292     296  US-2023-157847 2023-02-04  06/04/2023    Second Class
# 293     297  US-2023-164315 2023-02-04  08/04/2023  Standard Class
# 294     297  US-2023-164315 2023-02-04  08/04/2023  Standard Class
#
#     Customer ID  Customer Name      Segment Country/Region          City  ...  \
# 0      DP-13000  Darren Powers  Replacement  United States       Houston  ...
# 1      PO-19195  Phillina Ober        Other  United States    Naperville  ...
# 2      PO-19195  Phillina Ober        Other  United States    Naperville  ...
# 3      PO-19195  Phillina Ober        Other  United States    Naperville  ...
# 4      MB-18085     Mick Brown  Replacement  United States  Philadelphia  ...
# ..          ...            ...          ...            ...           ...  ...
# 290    SC-20020     Sam Craven  Replacement  United States       Houston  ...
# 291    SC-20020     Sam Craven  Replacement  United States       Houston  ...
# 292    SC-20020     Sam Craven  Replacement  United States       Houston  ...
# 293    RD-19585       Rob Dowd  Replacement  United States        Athens  ...
# 294    RD-19585       Rob Dowd  Replacement  United States        Athens  ...
#
#     Quantity Discount   Profit Total Sales Profit Margin Order Month  Year  \
# 0          2      0.2   5.5512      32.896     16.875000       March  2019
# 1          2      0.8  -5.4870       7.080    -77.500000       April  2019
# 2          3      0.2   4.2717      35.352     12.083333       April  2019
# 3          3      0.2 -64.7748     818.208     -7.916667       April  2019
# 4          3      0.2   4.8840      58.608      8.333333         May  2019
# ..       ...      ...      ...         ...           ...         ...   ...
# 290        7      0.2  10.4650     234.416      4.464286    February  2023
# 291        5      0.2   9.3520     133.600      7.000000    February  2023
# 292        5      0.2   9.3520     133.600      7.000000    February  2023
# 293        3      0.0   7.1280      47.520     15.000000    February  2023
# 294        3      0.0   7.1280      47.520     15.000000    February  2023
#
#      Yearly Sales  Orders per Year  Orders per Month
# 0       11167.479               22                 1
# 1       11167.479               22                 1
# 2       11167.479               22                 1
# 3       11167.479               22                 1
# 4       11167.479               22                 1
# ..            ...              ...               ...
# 290      1718.228               10                 3
# 291      1718.228               10                 3
# 292      1718.228               10                 3
# 293      1718.228               10                 3
# 294      1718.228               10                 3
#
# [295 rows x 27 columns]

# %% [markdown]
# ###*IV. DATA SUMMARIZATION*

# %% [markdown]
# 1) Descriptive Summarization:

# %%
# Calculate summary statistics
summary_stats = merged_df.describe()

# Transpose the summary statistics DataFrame to make it suitable for appending
summary_stats = summary_stats.transpose()

# Add the summary statistics row to the original DataFrame
merged_df = merged_df.append(summary_stats)

# Display the updated DataFrame with summary statistics
merged_df
# Out:
# <ipython-input-37-1491f2e0511b>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = merged_df.append(summary_stats)
#                     Row ID        Order ID Order Date   Ship Date  \
# 0                      1.0  US-2019-103800 2019-03-01  07/01/2019
# 1                      2.0  US-2019-112326 2019-04-01  08/01/2019
# 2                      3.0  US-2019-112326 2019-04-01  08/01/2019
# 3                      4.0  US-2019-112326 2019-04-01  08/01/2019
# 4                      5.0  US-2019-141817 2019-05-01  12/01/2019
# ...                    ...             ...        ...         ...
# Total Sales            NaN             NaN        NaT         NaN
# Profit Margin          NaN             NaN        NaT         NaN
# Yearly Sales_y         NaN             NaN        NaT         NaN
# Orders per Year_y      NaN             NaN        NaT         NaN
# Orders per Month_y     NaN             NaN        NaT         NaN
#
#                          Ship Mode Customer ID  Customer Name      Segment  \
# 0                   Standard Class    DP-13000  Darren Powers  Replacement
# 1                   Standard Class    PO-19195  Phillina Ober        Other
# 2                   Standard Class    PO-19195  Phillina Ober        Other
# 3                   Standard Class    PO-19195  Phillina Ober        Other
# 4                   Standard Class    MB-18085     Mick Brown  Replacement
# ...                            ...         ...            ...          ...
# Total Sales                    NaN         NaN            NaN          NaN
# Profit Margin                  NaN         NaN            NaN          NaN
# Yearly Sales_y                 NaN         NaN            NaN          NaN
# Orders per Year_y              NaN         NaN            NaN          NaN
# Orders per Month_y             NaN         NaN            NaN          NaN
#
#                    Country/Region          City  ... Orders per Year_y  \
# 0                   United States       Houston  ...             138.0
# 1                   United States    Naperville  ...             138.0
# 2                   United States    Naperville  ...             138.0
# 3                   United States    Naperville  ...             138.0
# 4                   United States  Philadelphia  ...             138.0
# ...                           ...           ...  ...               ...
# Total Sales                   NaN           NaN  ...               NaN
# Profit Margin                 NaN           NaN  ...               NaN
# Yearly Sales_y                NaN           NaN  ...               NaN
# Orders per Year_y             NaN           NaN  ...               NaN
# Orders per Month_y            NaN           NaN  ...               NaN
#
#                    Orders per Month_y  count          mean           std  \
# 0                                55.0    NaN           NaN           NaN
# 1                                 5.0    NaN           NaN           NaN
# 2                                 5.0    NaN           NaN           NaN
# 3                                 5.0    NaN           NaN           NaN
# 4                                 2.0    NaN           NaN           NaN
# ...                               ...    ...           ...           ...
# Total Sales                       NaN  297.0   1319.851684  8.219661e+03
# Profit Margin                     NaN  297.0      5.061956  1.885720e+01
# Yearly Sales_y                    NaN  297.0  75428.796000  1.457648e-11
# Orders per Year_y                 NaN  297.0    138.000000  0.000000e+00
# Orders per Month_y                NaN  297.0     33.936027  1.970781e+01
#
#                           min        25%        50%        75%            max
# 0                         NaN        NaN        NaN        NaN            NaN
# 1                         NaN        NaN        NaN        NaN            NaN
# 2                         NaN        NaN        NaN        NaN            NaN
# 3                         NaN        NaN        NaN        NaN            NaN
# 4                         NaN        NaN        NaN        NaN            NaN
# ...                       ...        ...        ...        ...            ...
# Total Sales             0.852     44.820    137.088    655.128  135830.880000
# Profit Margin         -87.500      2.000      8.000     13.125      47.993827
# Yearly Sales_y      75428.796  75428.796  75428.796  75428.796   75428.796000
# Orders per Year_y     138.000    138.000    138.000    138.000     138.000000
# Orders per Month_y      1.000     21.000     31.000     55.000      55.000000
#
# [311 rows x 38 columns]

# %% [markdown]
# We have alculated basic statistics such as mean, median, mode, standard deviation, etc., for numerical columns (e.g., Sales, Quantity, Profit).

# %% [markdown]
# 2) Segmented Summarization:

# %%
# Calculate summary statistics by segment
segment_summary = merged_df.groupby('Segment').agg({
    'Sales': 'sum',
    'Profit': 'mean',
    'Quantity': 'sum'
}).reset_index()

# Rename the index to match the columns of the original DataFrame
segment_summary = segment_summary.rename(columns={'Sales': 'Sales_Summary', 'Profit': 'Profit_Mean', 'Quantity': 'Quantity_Summary'})

# Add the segment summary row to the original DataFrame
merged_df = pd.concat([merged_df, segment_summary])

# Display the updated DataFrame with segment summary
merged_df
# Out:
#                     Row ID        Order ID Order Date   Ship Date  \
# 0                      1.0  US-2019-103800 2019-03-01  07/01/2019
# 1                      2.0  US-2019-112326 2019-04-01  08/01/2019
# 2                      3.0  US-2019-112326 2019-04-01  08/01/2019
# 3                      4.0  US-2019-112326 2019-04-01  08/01/2019
# 4                      5.0  US-2019-141817 2019-05-01  12/01/2019
# ...                    ...             ...        ...         ...
# Orders per Year_y      NaN             NaN        NaT         NaN
# Orders per Month_y     NaN             NaN        NaT         NaN
# 0                      NaN             NaN        NaT         NaN
# 1                      NaN             NaN        NaT         NaN
# 2                      NaN             NaN        NaT         NaN
#
#                          Ship Mode Customer ID  Customer Name      Segment  \
# 0                   Standard Class    DP-13000  Darren Powers  Replacement
# 1                   Standard Class    PO-19195  Phillina Ober        Other
# 2                   Standard Class    PO-19195  Phillina Ober        Other
# 3                   Standard Class    PO-19195  Phillina Ober        Other
# 4                   Standard Class    MB-18085     Mick Brown  Replacement
# ...                            ...         ...            ...          ...
# Orders per Year_y              NaN         NaN            NaN          NaN
# Orders per Month_y             NaN         NaN            NaN          NaN
# 0                              NaN         NaN            NaN        Other
# 1                              NaN         NaN            NaN  Replacement
# 2                              NaN         NaN            NaN    Servicing
#
#                    Country/Region          City  ...        mean        std  \
# 0                   United States       Houston  ...         NaN        NaN
# 1                   United States    Naperville  ...         NaN        NaN
# 2                   United States    Naperville  ...         NaN        NaN
# 3                   United States    Naperville  ...         NaN        NaN
# 4                   United States  Philadelphia  ...         NaN        NaN
# ...                           ...           ...  ...         ...        ...
# Orders per Year_y             NaN           NaN  ...  138.000000   0.000000
# Orders per Month_y            NaN           NaN  ...   33.936027  19.707814
# 0                             NaN           NaN  ...         NaN        NaN
# 1                             NaN           NaN  ...         NaN        NaN
# 2                             NaN           NaN  ...         NaN        NaN
#
#                       min    25%    50%    75%    max  Sales_Summary  \
# 0                     NaN    NaN    NaN    NaN    NaN            NaN
# 1                     NaN    NaN    NaN    NaN    NaN            NaN
# 2                     NaN    NaN    NaN    NaN    NaN            NaN
# 3                     NaN    NaN    NaN    NaN    NaN            NaN
# 4                     NaN    NaN    NaN    NaN    NaN            NaN
# ...                   ...    ...    ...    ...    ...            ...
# Orders per Year_y   138.0  138.0  138.0  138.0  138.0            NaN
# Orders per Month_y    1.0   21.0   31.0   55.0   55.0            NaN
# 0                     NaN    NaN    NaN    NaN    NaN      39733.726
# 1                     NaN    NaN    NaN    NaN    NaN      22242.611
# 2                     NaN    NaN    NaN    NaN    NaN      13452.459
#
#                     Profit_Mean  Quantity_Summary
# 0                           NaN               NaN
# 1                           NaN               NaN
# 2                           NaN               NaN
# 3                           NaN               NaN
# 4                           NaN               NaN
# ...                         ...               ...
# Orders per Year_y           NaN               NaN
# Orders per Month_y          NaN               NaN
# 0                     21.505589             217.0
# 1                     12.174644             597.0
# 2                     20.198098             278.0
#
# [314 rows x 41 columns]

# %% [markdown]
# Here we have summarized the data based on different segments (e.g., Segment, Region, Category, Sub-Category).

# %% [markdown]
# # Step 3 : Data Loading

# %% [markdown]
# For loading the data into any database getting the csv file of the merged dataframe i.e 'merged df'

# %%
# Saving the merged DataFrame to a new JSON file
merged_df.to_csv('merged_data.csv')

# %% [markdown]
# To connect to MongoDB from Google Colab and send a Json file to a MongoDB database, we need to use the pymongo library for Python
#
# 1) we have installed pymongo library
# 2) converted csv dataset to JSON format

# %%
# from pymongo import MongoClient

df = pd.read_json('/content/merged_data.json', lines=True)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-54-e2b58f9c857c> in <cell line: 3>()
#       1 # from pymongo import MongoClient
#       2
# ----> 3 df = pd.read_json('/content/merged_data.json', lines=True)
#       4 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     731         convert_axes = True
#     732
# --> 733     json_reader = JsonReader(
#     734         path_or_buf,
#     735         orient=orient,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors)
#     816                 raise ValueError("nrows can only be passed if lines=True")
#     817
# --> 818         data = self._get_data_from_filepath(filepath_or_buffer)
#     819         self.data = self._preprocess_data(data)
#     820
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in _get_data_from_filepath(self, filepath_or_buffer)
#     872             and not file_exists(filepath_or_buffer)
#     873         ):
# --> 874             raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     875
#     876         return filepath_or_buffer
#
# FileNotFoundError: File /content/merged_data.json does not exist

# %% [markdown]
# <h3><b>Connecting to Mongodb server and loading json data to mongodb atlas</b></h3>

# %%
import pymongo
import json

# Replace these values with your MongoDB Atlas connection string
mongo_uri = "mongodb+srv://<username>:<password>@cluster0.818yghy.mongodb.net/?retryWrites=true&w=majority&ssl=true"
database_name = "etl"
collection_name = "etl_updated"

# Connect to MongoDB Atlas
client = pymongo.MongoClient(mongo_uri)

# Access the database and collection
db = client[database_name]
collection = db[collection_name]

# Path to your JSON file
json_file_path = "merged_data.json"

# Load JSON data from file
with open(json_file_path, 'r') as file:
    json_data = json.load(file)

# Insert JSON data into MongoDB collection
collection.insert_many(json_data)

# Close the MongoDB connection
client.close()

print("Data loaded Succesfully!!")
